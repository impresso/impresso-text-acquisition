# %% [markdown]
# # Debug exploration of ANP (KB) and WW2 (SwissInfo) Radio Bulletins
#
# This notebook aims to perform a first rought exploration of the the data at hand, for the KB and SwissInfo radio bulletins.

# %% [markdown]
# ### Imports

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
import random
import time

# %% [markdown]
# ## KB ANP - Fetching some sample data through the API

# %% [markdown]
# - link to doc file: https://docs.google.com/document/d/1uLPaOZLdH5fntdu9vjL1VEwelKMaKQan/edit#heading=h.26in1rg
# - listing sets: http://services.kb.nl/mdo/oai?verb=ListSets
# - listing the contents of ANP set: http://services.kb.nl/mdo/oai?verb=ListIdentifiers&set=anp&metadataPrefix=didl
# - listing the contents of one ANP record: http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:10:01:1:mpeg21&metadataPrefix=didl
# - Obtaining the image for this one ANP record: http://resolver.kb.nl/resolve?urn=anp:1937:10:01:1:mpeg21:image
# - Obtaining the OCR for this one ANP record (ALTO): http://resolver.kb.nl/resolve?urn=anp:1937:10:01:1:mpeg21:alto
# - Obtainign the plain text ocr: https://resolver.kb.nl/resolve?urn=anp:1937:10:01:1:mpeg21:ocr

# %%
anp_set_url = "http://services.kb.nl/mdo/oai?verb=ListIdentifiers&set=anp&metadataPrefix=didl"

resp_anp_set_first_p = requests.get(anp_set_url)
contents_anp_set_first_p = BeautifulSoup(resp_anp_set_first_p.content, "xml")

contents_anp_set_first_p
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/          http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">
# <responseDate>2025-01-16T14:10:57.620Z</responseDate>
# <request metadataPrefix="didl" set="anp" verb="ListIdentifiers">http://services.kb.nl/mdo/oai	</request>
# <ListIdentifiers>
# <header>
# <identifier>anp:anp:1937:10:01:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.050Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:01:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:01:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:02:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:02:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:02:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:02:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:02:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:03:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:03:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:03:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:03:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.238Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:03:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:04:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:04:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:04:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.300Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:04:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.300Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:04:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.300Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:04:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.316Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:05:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.316Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:05:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.316Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:05:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.332Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:05:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.332Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.347Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.363Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.363Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.378Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.394Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.394Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.410Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.410Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:06:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.472Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.472Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.472Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:21:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:24:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.503Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:23:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.503Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:22:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.503Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:26:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:25:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:07:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.628Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.628Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:21:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:08:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.753Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:09:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.753Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:09:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.753Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:09:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:09:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:09:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:09:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:09:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:22:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:21:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:23:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.878Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:24:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:25:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.957Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.957Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.957Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.972Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.988Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.988Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.988Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:10:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:09.988Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.003Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.003Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.003Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.003Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.019Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.019Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.019Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:11:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.035Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:12:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.035Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:12:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.035Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:12:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.035Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:12:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.050Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:12:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.050Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:12:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.050Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:13:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.050Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:13:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.066Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:13:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.066Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:13:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.082Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:13:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.082Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:13:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.082Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:13:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.082Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:14:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.097Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:14:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.097Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:14:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.097Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:14:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.097Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:14:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.113Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.113Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:14:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.113Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.128Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.128Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.128Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.128Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.144Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.144Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.144Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:15:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:16:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:16:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:16:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:16:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:16:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.238Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.238Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.238Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.253Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.253Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.253Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.269Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.269Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:17:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.269Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:18:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.269Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:18:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:18:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:18:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:18:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.300Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:18:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.300Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:18:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.300Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:19:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.363Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:19:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.363Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:19:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.378Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:19:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.378Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:19:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.378Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:19:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.378Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:19:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.394Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.394Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.394Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.394Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.410Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:20:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:21:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:21:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:21:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:21:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:21:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:21:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:21:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:22:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:22:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:22:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:22:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:22:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.503Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.503Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.503Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:23:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:21:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:22:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:25:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.628Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:24:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.628Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:25:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:25:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:25:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:25:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:26:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:25:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:26:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:26:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:26:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:26:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:26:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:26:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:27:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:27:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:27:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:27:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:27:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:27:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:28:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:28:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:28:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:28:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:28:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.753Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.753Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.753Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:28:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.753Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:29:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:30:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.878Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.878Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.878Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.878Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:21:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:22:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.910Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.910Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.910Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:23:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.910Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.925Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.925Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.925Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.925Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:10:31:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:10.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.332Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.332Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.332Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.347Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.347Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.347Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.347Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.363Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.363Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.363Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.379Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.379Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:01:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.379Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:02:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.410Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:02:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.410Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:02:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.410Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:02:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.410Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:02:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:02:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.425Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.441Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.457Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.472Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.472Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.472Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:03:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:04:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:04:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:04:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.488Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:04:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.504Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:04:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.504Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:04:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.504Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:04:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:05:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:05:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.519Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:05:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:05:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:05:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:05:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.535Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.550Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.566Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:06:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.582Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.629Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.629Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.629Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:21:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:22:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:25:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:24:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:23:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:27:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:28:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:29:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:26:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:30:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:31:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.754Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:08:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.754Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:08:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.754Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:07:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.754Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:08:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:11:08:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:13.769Z</datestamp>
# </header>
# <header>
# ...
# </header>
# <header>
# <identifier>anp:anp:1937:12:05:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:05:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:05:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.597Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:05:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:05:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:05:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.613Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:06:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.629Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:06:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.629Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:06:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:06:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:07:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.644Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:07:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:07:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:07:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.660Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:08:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:08:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:08:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:07:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.675Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:08:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:08:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.691Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:09:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:09:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:08:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:09:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.707Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:09:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:09:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:09:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.722Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:10:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.738Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:10:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.754Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:10:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.754Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:10:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.754Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:11:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:10:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:10:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:10:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.769Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:11:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:11:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:11:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:11:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.785Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:11:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:11:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:12:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.800Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:12:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:12:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:12:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.816Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:12:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:12:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:12:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:13:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.832Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:13:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:13:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.847Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:14:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:13:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:14:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.863Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:14:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.879Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:14:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.879Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:14:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:15:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:14:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:14:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.894Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:15:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.910Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:15:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.910Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:15:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.910Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.925Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.925Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.925Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.941Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.988Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:15.988Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:17:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.004Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:16:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.004Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:17:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.019Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:17:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.019Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:17:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.019Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:17:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.035Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:17:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.035Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:18:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.035Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:18:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.050Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:18:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.050Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:18:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.066Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:18:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.066Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:18:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.066Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:10:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.082Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:12:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.082Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:11:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.082Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:13:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.097Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:15:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.097Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:14:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.097Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:16:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.113Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:18:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.113Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:17:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.113Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:19:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.129Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:20:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.129Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.129Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:21:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.144Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:23:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.144Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:22:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.144Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:24:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:27:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:26:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:25:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.160Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:28:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:30:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:29:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.175Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:31:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:33:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:32:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.191Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.207Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:8:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:7:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.222Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:19:9:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.238Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:20:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.238Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:20:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.238Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:20:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.254Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:20:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.254Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:20:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.254Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:20:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.269Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:21:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.269Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:21:2:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:21:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.285Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:21:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.316Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:21:6:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.316Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:21:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.316Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:22:1:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.332Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:22:4:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.332Z</datestamp>
# </header>
# <header>
# <identifier>anp:anp:1937:12:22:3:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:16.332Z</datestamp>
# </header>
# <resumptionToken>anp!2008-09-24T09:09:16.332Z!!didl!2317275</resumptionToken> </ListIdentifiers>
# </OAI-PMH>

# %% [markdown]
# #### Listing all identifiers in the ANP Collection

# %%
anp_set_url = "http://services.kb.nl/mdo/oai?verb=ListIdentifiers&set=anp&metadataPrefix=didl"

# %%
anp_identifiers = []

# %%
r = requests.post(url=anp_set_url, headers={'Connection':'close'})

# %%
resump_token = "anp!2008-09-24T09:13:24.099Z!!didl!2322875"

# %%
resump_token = ""
it_idx = 0
while resump_token is not None:
    if resump_token!="":
        anp_set_url_with_token = f"{anp_set_url}&resumptionToken={resump_token}"
    else:
        anp_set_url_with_token = anp_set_url

    print(f"-Iteration n°{it_idx}: sending request")
    with requests.Session() as s:
        time.sleep(0.01)
        #s.get('http://google.com')
        resp_anp_set = s.get(anp_set_url_with_token)
    print(f"     Finished request, extracting contents")
    contents_anp_set = BeautifulSoup(resp_anp_set.content, "xml")
    
    len_before = len(anp_identifiers)
    anp_identifiers.extend(contents_anp_set.find_all("identifier"))
    print(f"    Iter n°{it_idx}: anp_identifiers went from {len_before} to {len(anp_identifiers)} identifiers")
    if contents_anp_set.resumptionToken is not None:
        resump_token = contents_anp_set.resumptionToken.get_text()
        print(f"    Iter n°{it_idx}: resump_token = {resump_token}")
    else:
        resump_token = None
        print(f"    Iter n°{it_idx}: resump_token = {resump_token}, Stopping now the iterations")
    it_idx += 1
# Out:
# -Iteration n°0: sending request
#      Finished request, extracting contents
#     Iter n°0: anp_identifiers went from 0 to 800 identifiers
#     Iter n°0: resump_token = anp!2008-09-24T09:09:16.332Z!!didl!2317275
# -Iteration n°1: sending request
#      Finished request, extracting contents
#     Iter n°1: anp_identifiers went from 800 to 1600 identifiers
#     Iter n°1: resump_token = anp!2008-09-24T09:09:23.363Z!!didl!2318075
# -Iteration n°2: sending request
#      Finished request, extracting contents
#     Iter n°2: anp_identifiers went from 1600 to 2400 identifiers
#     Iter n°2: resump_token = anp!2008-09-24T09:11:12.895Z!!didl!2318875
# -Iteration n°3: sending request
#      Finished request, extracting contents
#     Iter n°3: anp_identifiers went from 2400 to 3200 identifiers
#     Iter n°3: resump_token = anp!2008-09-24T09:11:20.239Z!!didl!2319675
# -Iteration n°4: sending request
#      Finished request, extracting contents
#     Iter n°4: anp_identifiers went from 3200 to 4000 identifiers
#     Iter n°4: resump_token = anp!2008-09-24T09:11:26.661Z!!didl!2320475
# -Iteration n°5: sending request
#      Finished request, extracting contents
#     Iter n°5: anp_identifiers went from 4000 to 4800 identifiers
#     Iter n°5: resump_token = anp!2008-09-24T09:11:31.067Z!!didl!2321275
# -Iteration n°6: sending request
#      Finished request, extracting contents
#     Iter n°6: anp_identifiers went from 4800 to 5600 identifiers
#     Iter n°6: resump_token = anp!2008-09-24T09:13:16.568Z!!didl!2322075
# -Iteration n°7: sending request
#      Finished request, extracting contents
#     Iter n°7: anp_identifiers went from 5600 to 6400 identifiers
#     Iter n°7: resump_token = anp!2008-09-24T09:13:24.099Z!!didl!2322875
# -Iteration n°8: sending request
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 13
#      11     time.sleep(0.01)
#      12     #s.get('http://google.com')
# ---> 13     resp_anp_set = s.get(anp_set_url_with_token)
#      14 print(f"     Finished request, extracting contents")
#      15 contents_anp_set = BeautifulSoup(resp_anp_set.content, "xml")
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /scratch/piconti/.conda/envs/text_acquisition/lib/python3.11/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))

# %%
def fetch_identifiers_from_API(anp_set_url, it_idx = 0, resump_token = "", other_identifiers_path = None):

    if other_identifiers_path is not None and resump_token!='':
        with open(other_identifiers_path, 'r') as f_in:
            anp_identifiers = json.load(f_in)

        anp_identifiers = list(set(anp_identifiers))
        print(f"Starting sending requests, with resump_token={resump_token} and {len(anp_identifiers)} already fetched.")
    else:
        anp_identifiers = []
        print(f"Starting sending requests, from scratch.")
    
    new_identifiers = []
    
    while resump_token is not None:
        if resump_token!="":
            anp_set_url_with_token = f"{anp_set_url}&resumptionToken={resump_token}"
        else:
            anp_set_url_with_token = anp_set_url

        print(f"-Iteration n°{it_idx}: sending request")
        try:
            with requests.Session() as s:
                time.sleep(0.05)
                #s.get('http://google.com')
                resp_anp_set = s.get(anp_set_url_with_token)
            print(f"     Finished request, extracting contents")
            contents_anp_set = BeautifulSoup(resp_anp_set.content, "xml")
        
            len_before = len(new_identifiers)
            new_identifiers.extend(contents_anp_set.find_all("identifier"))
            print(f"    Iter n°{it_idx}: new_identifiers went from {len_before} to {len(new_identifiers)} identifiers")
            if contents_anp_set.resumptionToken is not None:
                resump_token = contents_anp_set.resumptionToken.get_text()
                print(f"    Iter n°{it_idx}: resump_token = {resump_token}")
            else:
                resump_token = None
                print(f"    Iter n°{it_idx}: resump_token = {resump_token}, Stopping now the iterations")
            it_idx += 1

        except Exception as e:
            print(f"Exception occurred, returning the current list of {len(new_identifiers)} identifiers; {e}")

        text_identifiers = [i.get_text() for i in new_identifiers]

        anp_identifiers.extend(text_identifiers)
        # writing the current results to ensure they are not lost
        if other_identifiers_path is not None:
            with open(other_identifiers_path, 'w') as f_out:
                json.dump(list(set(anp_identifiers)), f_out)
                
    return anp_identifiers

# %% [markdown]
# I keep getting blocked from the APi, so could only fetch 1600 identifiers.
# Will sample some from these already, but hard to know how many elements there are in the ANP collection

# %%
# show first five and last 5 fetched identifiers
anp_identifiers[:5], anp_identifiers[-5:]
# Out:
# ([], [])

# %%
len(anp_identifiers)
# Out:
# 6400

# %% [markdown]
# All fetched identifiers are more or less from the same period, but we can fetch randomly 3-5 of them.

# %% [markdown]
# #### Write the fetched identifiers to a txt file

# %%
kb_radio_sample_path = "/home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio"
kb_radio_ids_file = os.path.join(kb_radio_sample_path, "anp_identifiers_2.json")

# %%
anp_identifiers = fetch_identifiers_from_API(anp_set_url, other_identifiers_path=kb_radio_ids_file)
# Out:
# Starting sending requests, from scratch.
# -Iteration n°0: sending request
#      Finished request, extracting contents
#     Iter n°0: anp_identifiers went from 0 to 800 identifiers
#     Iter n°0: resump_token = anp!2008-09-24T09:09:16.332Z!!didl!2317275
# -Iteration n°1: sending request
#      Finished request, extracting contents
#     Iter n°1: anp_identifiers went from 800 to 1600 identifiers
#     Iter n°1: resump_token = anp!2008-09-24T09:09:23.363Z!!didl!2318075
# -Iteration n°2: sending request
#      Finished request, extracting contents
#     Iter n°2: anp_identifiers went from 1600 to 2400 identifiers
#     Iter n°2: resump_token = anp!2008-09-24T09:11:12.895Z!!didl!2318875
# -Iteration n°3: sending request
# Exception occurred, returning the current list of 2400 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°3: sending request
#      Finished request, extracting contents
#     Iter n°3: anp_identifiers went from 2400 to 3200 identifiers
#     Iter n°3: resump_token = anp!2008-09-24T09:11:20.239Z!!didl!2319675
# -Iteration n°4: sending request
#      Finished request, extracting contents
#     Iter n°4: anp_identifiers went from 3200 to 4000 identifiers
#     Iter n°4: resump_token = anp!2008-09-24T09:11:26.661Z!!didl!2320475
# -Iteration n°5: sending request
#      Finished request, extracting contents
#     Iter n°5: anp_identifiers went from 4000 to 4800 identifiers
#     Iter n°5: resump_token = anp!2008-09-24T09:11:31.067Z!!didl!2321275
# -Iteration n°6: sending request
#      Finished request, extracting contents
#     Iter n°6: anp_identifiers went from 4800 to 5600 identifiers
#     Iter n°6: resump_token = anp!2008-09-24T09:13:16.568Z!!didl!2322075
# -Iteration n°7: sending request
#      Finished request, extracting contents
#     Iter n°7: anp_identifiers went from 5600 to 6400 identifiers
#     Iter n°7: resump_token = anp!2008-09-24T09:13:24.099Z!!didl!2322875
# -Iteration n°8: sending request
#      Finished request, extracting contents
#     Iter n°8: anp_identifiers went from 6400 to 7200 identifiers
#     Iter n°8: resump_token = anp!2008-09-24T09:13:29.083Z!!didl!2323675
# -Iteration n°9: sending request
#      Finished request, extracting contents
#     Iter n°9: anp_identifiers went from 7200 to 8000 identifiers
#     Iter n°9: resump_token = anp!2008-09-24T09:14:29.771Z!!didl!2324475
# -Iteration n°10: sending request

# %%
anp_identifiers = fetch_identifiers_from_API(anp_set_url, it_idx=10, resump_token="anp!2008-09-24T09:14:29.771Z!!didl!2324475", other_identifiers_path=kb_radio_ids_file)
# Out:
# Starting sending requests, with resump_token=anp!2008-09-24T09:14:29.771Z!!didl!2324475 and 26400 already fetched.
# -Iteration n°10: sending request
#      Finished request, extracting contents
#     Iter n°10: new_identifiers went from 0 to 800 identifiers
#     Iter n°10: resump_token = anp!2008-09-24T09:14:34.646Z!!didl!2325275
# -Iteration n°11: sending request
#      Finished request, extracting contents
#     Iter n°11: new_identifiers went from 800 to 1600 identifiers
#     Iter n°11: resump_token = anp!2008-09-24T09:14:40.084Z!!didl!2326075
# -Iteration n°12: sending request
# Exception occurred, returning the current list of 1600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°12: sending request
#      Finished request, extracting contents
#     Iter n°12: new_identifiers went from 1600 to 2400 identifiers
#     Iter n°12: resump_token = anp!2008-09-24T09:15:04.600Z!!didl!2326875
# -Iteration n°13: sending request
# Exception occurred, returning the current list of 2400 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°13: sending request
#      Finished request, extracting contents
#     Iter n°13: new_identifiers went from 2400 to 3200 identifiers
#     Iter n°13: resump_token = anp!2008-09-24T09:15:10.443Z!!didl!2327705
# -Iteration n°14: sending request
# Exception occurred, returning the current list of 3200 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°14: sending request
#      Finished request, extracting contents
#     Iter n°14: new_identifiers went from 3200 to 4000 identifiers
#     Iter n°14: resump_token = anp!2008-09-24T09:15:17.037Z!!didl!2328505
# -Iteration n°15: sending request
#      Finished request, extracting contents
#     Iter n°15: new_identifiers went from 4000 to 4800 identifiers
#     Iter n°15: resump_token = anp!2008-09-24T09:15:22.147Z!!didl!2329305
# -Iteration n°16: sending request
#      Finished request, extracting contents
#     Iter n°16: new_identifiers went from 4800 to 5600 identifiers
#     Iter n°16: resump_token = anp!2008-09-24T09:15:27.631Z!!didl!2330105
# -Iteration n°17: sending request
# Exception occurred, returning the current list of 5600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°17: sending request
#      Finished request, extracting contents
#     Iter n°17: new_identifiers went from 5600 to 6400 identifiers
#     Iter n°17: resump_token = anp!2008-09-24T09:15:34.647Z!!didl!2330905
# -Iteration n°18: sending request
#      Finished request, extracting contents
#     Iter n°18: new_identifiers went from 6400 to 7200 identifiers
#     Iter n°18: resump_token = anp!2008-09-24T09:15:38.678Z!!didl!2331705
# -Iteration n°19: sending request
#      Finished request, extracting contents
#     Iter n°19: new_identifiers went from 7200 to 8000 identifiers
#     Iter n°19: resump_token = anp!2008-09-24T09:15:45.303Z!!didl!2332505
# -Iteration n°20: sending request
#      Finished request, extracting contents
#     Iter n°20: new_identifiers went from 8000 to 8800 identifiers
#     Iter n°20: resump_token = anp!2008-09-24T09:15:49.537Z!!didl!2333305
# -Iteration n°21: sending request
# Exception occurred, returning the current list of 8800 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°21: sending request
# Exception occurred, returning the current list of 8800 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°21: sending request
# Exception occurred, returning the current list of 8800 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°21: sending request

# %%
anp_identifiers = fetch_identifiers_from_API(anp_set_url, it_idx=20, resump_token="anp!2008-09-24T09:15:49.537Z!!didl!2333305", other_identifiers_path=kb_radio_ids_file)
# Out:
# Starting sending requests, with resump_token=anp!2008-09-24T09:15:49.537Z!!didl!2333305 and 26400 already fetched.
# -Iteration n°20: sending request
# Exception occurred, returning the current list of 0 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°20: sending request
#      Finished request, extracting contents
#     Iter n°20: new_identifiers went from 0 to 800 identifiers
#     Iter n°20: resump_token = anp!2008-09-24T09:15:54.412Z!!didl!2334105
# -Iteration n°21: sending request

# %%
anp_identifiers = fetch_identifiers_from_API(anp_set_url, it_idx=21, resump_token="anp!2008-09-24T09:15:54.412Z!!didl!2334105", other_identifiers_path=kb_radio_ids_file)
# Out:
# Starting sending requests, with resump_token=anp!2008-09-24T09:15:54.412Z!!didl!2334105 and 26400 already fetched.
# -Iteration n°21: sending request
#      Finished request, extracting contents
#     Iter n°21: new_identifiers went from 0 to 800 identifiers
#     Iter n°21: resump_token = anp!2008-09-24T09:15:58.975Z!!didl!2334905
# -Iteration n°22: sending request
# Exception occurred, returning the current list of 800 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°22: sending request
#      Finished request, extracting contents
#     Iter n°22: new_identifiers went from 800 to 1600 identifiers
#     Iter n°22: resump_token = anp!2008-09-24T09:16:02.928Z!!didl!2335705
# -Iteration n°23: sending request
#      Finished request, extracting contents
#     Iter n°23: new_identifiers went from 1600 to 2400 identifiers
#     Iter n°23: resump_token = anp!2008-09-24T09:16:06.553Z!!didl!2336505
# -Iteration n°24: sending request
#      Finished request, extracting contents
#     Iter n°24: new_identifiers went from 2400 to 3200 identifiers
#     Iter n°24: resump_token = anp!2008-09-24T09:16:10.647Z!!didl!2337305
# -Iteration n°25: sending request
#      Finished request, extracting contents
#     Iter n°25: new_identifiers went from 3200 to 4000 identifiers
#     Iter n°25: resump_token = anp!2008-09-24T09:16:26.772Z!!didl!2338105
# -Iteration n°26: sending request
#      Finished request, extracting contents
#     Iter n°26: new_identifiers went from 4000 to 4800 identifiers
#     Iter n°26: resump_token = anp!2008-09-24T09:16:30.850Z!!didl!2338905
# -Iteration n°27: sending request
#      Finished request, extracting contents
#     Iter n°27: new_identifiers went from 4800 to 5600 identifiers
#     Iter n°27: resump_token = anp!2008-09-24T09:16:36.069Z!!didl!2339705
# -Iteration n°28: sending request
#      Finished request, extracting contents
#     Iter n°28: new_identifiers went from 5600 to 6400 identifiers
#     Iter n°28: resump_token = anp!2008-09-24T09:16:39.053Z!!didl!2340505
# -Iteration n°29: sending request
#      Finished request, extracting contents
#     Iter n°29: new_identifiers went from 6400 to 7200 identifiers
#     Iter n°29: resump_token = anp!2008-09-24T09:16:46.710Z!!didl!2341305
# -Iteration n°30: sending request
#      Finished request, extracting contents
#     Iter n°30: new_identifiers went from 7200 to 8000 identifiers
#     Iter n°30: resump_token = anp!2008-09-24T09:16:49.772Z!!didl!2342105
# -Iteration n°31: sending request
#      Finished request, extracting contents
#     Iter n°31: new_identifiers went from 8000 to 8800 identifiers
#     Iter n°31: resump_token = anp!2008-09-24T09:16:52.678Z!!didl!2342905
# -Iteration n°32: sending request
#      Finished request, extracting contents
#     Iter n°32: new_identifiers went from 8800 to 9600 identifiers
#     Iter n°32: resump_token = anp!2008-09-24T09:16:58.178Z!!didl!2343706
# -Iteration n°33: sending request
#      Finished request, extracting contents
#     Iter n°33: new_identifiers went from 9600 to 10400 identifiers
#     Iter n°33: resump_token = anp!2008-09-24T09:17:01.210Z!!didl!2344506
# -Iteration n°34: sending request

# %%
anp_identifiers = fetch_identifiers_from_API(anp_set_url, it_idx=34, resump_token="anp!2008-09-24T09:17:01.210Z!!didl!2344506", other_identifiers_path=kb_radio_ids_file)
# Out:
# Starting sending requests, with resump_token=anp!2008-09-24T09:17:01.210Z!!didl!2344506 and 28000 already fetched.
# -Iteration n°34: sending request
#      Finished request, extracting contents
#     Iter n°34: new_identifiers went from 0 to 800 identifiers
#     Iter n°34: resump_token = anp!2008-09-24T09:17:06.460Z!!didl!2345306
# -Iteration n°35: sending request
# Exception occurred, returning the current list of 800 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°35: sending request
#      Finished request, extracting contents
#     Iter n°35: new_identifiers went from 800 to 1600 identifiers
#     Iter n°35: resump_token = anp!2008-09-24T09:17:09.960Z!!didl!2346106
# -Iteration n°36: sending request
#      Finished request, extracting contents
#     Iter n°36: new_identifiers went from 1600 to 2400 identifiers
#     Iter n°36: resump_token = anp!2008-09-24T09:17:12.866Z!!didl!2346906
# -Iteration n°37: sending request
#      Finished request, extracting contents
#     Iter n°37: new_identifiers went from 2400 to 3200 identifiers
#     Iter n°37: resump_token = anp!2008-09-24T09:17:18.007Z!!didl!2347706
# -Iteration n°38: sending request
#      Finished request, extracting contents
#     Iter n°38: new_identifiers went from 3200 to 4000 identifiers
#     Iter n°38: resump_token = anp!2008-09-24T09:17:20.882Z!!didl!2348506
# -Iteration n°39: sending request
#      Finished request, extracting contents
#     Iter n°39: new_identifiers went from 4000 to 4800 identifiers
#     Iter n°39: resump_token = anp!2008-09-24T09:17:25.929Z!!didl!2349306
# -Iteration n°40: sending request
#      Finished request, extracting contents
#     Iter n°40: new_identifiers went from 4800 to 5600 identifiers
#     Iter n°40: resump_token = anp!2008-09-24T09:17:28.804Z!!didl!2350106
# -Iteration n°41: sending request
#      Finished request, extracting contents
#     Iter n°41: new_identifiers went from 5600 to 6400 identifiers
#     Iter n°41: resump_token = anp!2008-09-24T09:17:34.350Z!!didl!2350906
# -Iteration n°42: sending request
#      Finished request, extracting contents
#     Iter n°42: new_identifiers went from 6400 to 7200 identifiers
#     Iter n°42: resump_token = anp!2008-09-24T09:17:37.210Z!!didl!2351706
# -Iteration n°43: sending request
#      Finished request, extracting contents
#     Iter n°43: new_identifiers went from 7200 to 8000 identifiers
#     Iter n°43: resump_token = anp!2008-09-24T09:17:40.210Z!!didl!2352506
# -Iteration n°44: sending request
#      Finished request, extracting contents
#     Iter n°44: new_identifiers went from 8000 to 8800 identifiers
#     Iter n°44: resump_token = anp!2008-09-24T09:17:45.601Z!!didl!2353306
# -Iteration n°45: sending request
#      Finished request, extracting contents
#     Iter n°45: new_identifiers went from 8800 to 9600 identifiers
#     Iter n°45: resump_token = anp!2008-09-24T09:17:48.772Z!!didl!2354106
# -Iteration n°46: sending request
#      Finished request, extracting contents
#     Iter n°46: new_identifiers went from 9600 to 10400 identifiers
#     Iter n°46: resump_token = anp!2008-09-24T09:17:53.679Z!!didl!2354906
# -Iteration n°47: sending request
#      Finished request, extracting contents
#     Iter n°47: new_identifiers went from 10400 to 11200 identifiers
#     Iter n°47: resump_token = anp!2008-09-24T09:17:56.741Z!!didl!2355706
# -Iteration n°48: sending request
#      Finished request, extracting contents
#     Iter n°48: new_identifiers went from 11200 to 12000 identifiers
#     Iter n°48: resump_token = anp!2008-09-24T09:18:01.773Z!!didl!2356506
# -Iteration n°49: sending request
# Exception occurred, returning the current list of 12000 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°49: sending request
#      Finished request, extracting contents
#     Iter n°49: new_identifiers went from 12000 to 12800 identifiers
#     Iter n°49: resump_token = anp!2008-09-24T09:18:04.663Z!!didl!2357306
# -Iteration n°50: sending request
#      Finished request, extracting contents
#     Iter n°50: new_identifiers went from 12800 to 13600 identifiers
#     Iter n°50: resump_token = anp!2008-09-24T09:18:10.148Z!!didl!2358106
# -Iteration n°51: sending request
#      Finished request, extracting contents
#     Iter n°51: new_identifiers went from 13600 to 14400 identifiers
#     Iter n°51: resump_token = anp!2008-09-24T09:18:12.991Z!!didl!2358906
# -Iteration n°52: sending request
#      Finished request, extracting contents
#     Iter n°52: new_identifiers went from 14400 to 15200 identifiers
#     Iter n°52: resump_token = anp!2008-09-24T09:18:15.929Z!!didl!2359706
# -Iteration n°53: sending request
#      Finished request, extracting contents
#     Iter n°53: new_identifiers went from 15200 to 16000 identifiers
#     Iter n°53: resump_token = anp!2008-09-24T09:26:59.854Z!!didl!2360506
# -Iteration n°54: sending request
# Exception occurred, returning the current list of 16000 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°54: sending request
# Exception occurred, returning the current list of 16000 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°54: sending request
# Exception occurred, returning the current list of 16000 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°54: sending request
# Exception occurred, returning the current list of 16000 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°54: sending request
#      Finished request, extracting contents
#     Iter n°54: new_identifiers went from 16000 to 16800 identifiers
#     Iter n°54: resump_token = anp!2008-09-24T09:27:03.510Z!!didl!2361306
# -Iteration n°55: sending request
#      Finished request, extracting contents
#     Iter n°55: new_identifiers went from 16800 to 17600 identifiers
#     Iter n°55: resump_token = anp!2008-09-24T09:27:09.714Z!!didl!2362106
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# Exception occurred, returning the current list of 17600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°56: sending request
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 anp_identifiers = fetch_identifiers_from_API(anp_set_url, it_idx=34, resump_token="anp!2008-09-24T09:17:01.210Z!!didl!2344506", other_identifiers_path=kb_radio_ids_file)
#
# Cell In[3], line 26, in fetch_identifiers_from_API(anp_set_url, it_idx, resump_token, other_identifiers_path)
#      24     time.sleep(0.05)
#      25     #s.get('http://google.com')
# ---> 26     resp_anp_set = s.get(anp_set_url_with_token)
#      27 print(f"     Finished request, extracting contents")
#      28 contents_anp_set = BeautifulSoup(resp_anp_set.content, "xml")
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
anp_identifiers = fetch_identifiers_from_API(anp_set_url, it_idx=56, resump_token="anp!2008-09-24T09:27:09.714Z!!didl!2362106", other_identifiers_path=kb_radio_ids_file)
# Out:
# Starting sending requests, with resump_token=anp!2008-09-24T09:27:09.714Z!!didl!2362106 and 46400 already fetched.
# -Iteration n°56: sending request
#      Finished request, extracting contents
#     Iter n°56: new_identifiers went from 0 to 800 identifiers
#     Iter n°56: resump_token = anp!2008-09-24T09:27:13.135Z!!didl!2362906
# -Iteration n°57: sending request
#      Finished request, extracting contents
#     Iter n°57: new_identifiers went from 800 to 1600 identifiers
#     Iter n°57: resump_token = anp!2008-09-24T09:27:15.917Z!!didl!2363706
# -Iteration n°58: sending request
# Exception occurred, returning the current list of 1600 identifiers; ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# -Iteration n°58: sending request
#      Finished request, extracting contents
#     Iter n°58: new_identifiers went from 1600 to 2400 identifiers
#     Iter n°58: resump_token = anp!2008-09-24T09:27:18.667Z!!didl!2364506
# -Iteration n°59: sending request
#      Finished request, extracting contents
#     Iter n°59: new_identifiers went from 2400 to 3200 identifiers
#     Iter n°59: resump_token = anp!2008-09-24T09:27:26.823Z!!didl!2365306
# -Iteration n°60: sending request
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 anp_identifiers = fetch_identifiers_from_API(anp_set_url, it_idx=56, resump_token="anp!2008-09-24T09:27:09.714Z!!didl!2362106", other_identifiers_path=kb_radio_ids_file)
#
# Cell In[8], line 26, in fetch_identifiers_from_API(anp_set_url, it_idx, resump_token, other_identifiers_path)
#      24     time.sleep(0.05)
#      25     #s.get('http://google.com')
# ---> 26     resp_anp_set = s.get(anp_set_url_with_token)
#      27 print(f"     Finished request, extracting contents")
#      28 contents_anp_set = BeautifulSoup(resp_anp_set.content, "xml")
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /scratch/piconti/.conda/envs/text_prep/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# save the currently fetched identifiers to disk
text_identifiers = [i.get_text() for i in anp_identifiers]

with open(kb_radio_ids_file, 'w') as f_out:
    json.dump(text_identifiers, f_out)

# %% [markdown]
# Read back the data that was saved

# %%
with open(kb_radio_ids_file, 'r') as f_in:
    identifiers_data = json.load(f_in)

len(identifiers_data), identifiers_data[:5], identifiers_data[-5:]
# Out:
# (1600,
#  ['anp:anp:1937:10:01:1:mpeg21',
#   'anp:anp:1937:10:01:2:mpeg21',
#   'anp:anp:1937:10:01:3:mpeg21',
#   'anp:anp:1937:10:02:1:mpeg21',
#   'anp:anp:1937:10:02:2:mpeg21'],
#  ['anp:anp:1937:07:09:5:mpeg21',
#   'anp:anp:1937:07:09:4:mpeg21',
#   'anp:anp:1937:07:10:2:mpeg21',
#   'anp:anp:1937:07:10:1:mpeg21',
#   'anp:anp:1937:07:10:3:mpeg21'])

# %% [markdown]
# ### Sample a few examples and save the metadata, images, ALTO and OCR plain text to disk to start working

# %%
sample_ids = random.sample(identifiers_data, 5)
sample_ids
# Out:
# ['anp:anp:1937:03:01:5:mpeg21',
#  'anp:anp:1937:03:25:4:mpeg21',
#  'anp:anp:1937:03:02:3:mpeg21',
#  'anp:anp:1937:12:31:5:mpeg21',
#  'anp:anp:1937:11:28:1:mpeg21']

# %%
# define the URIs to fetch the required information with the identifier
metadata_uri = "http://services.kb.nl/mdo/oai?verb=GetRecord&identifier={id}&metadataPrefix=didl"
image_uri = "http://resolver.kb.nl/resolve?urn={id}:image"
alto_uri = "http://resolver.kb.nl/resolve?urn={id}:alto"
ocr_uri = "http://resolver.kb.nl/resolve?urn={id}:ocr"

# %%
def send_request(identifier, idx, uri, data_elem):

    print(f"{identifier} ({idx+1}) - sending the resquest for {data_elem}, uri={uri}")
    resp = requests.get(uri)
    if resp.status_code == 200:
        if data_elem == 'image':
            return resp.content
        else:
            return BeautifulSoup(resp.content, "xml")
    else:
        print(f"{identifier} ({idx+1}) - Status code for request for {data_elem} was {resp.status_code} (uri =  {uri}).")
        return None

# %%
fetched_data = {}

# %%
# remove the first "anp:" for some requests
sample_ids[0][4:]
# Out:
# 'anp:1937:03:01:5:mpeg21'

# %% [markdown]
# #### Query the API for each of the sampled items

# %%
def fetch_data_for_identifiers(ids):
    fetched_data = {}
    for idx, ident in enumerate(ids):
        print(f"Fetching the data for identifier {ident} ({idx+1}/{len(sample_ids)})")
        # for images, ocr, and alto, the firs "anp:" should be removed
        fetched_for_id = {
            'metadata': send_request(ident, idx, metadata_uri.format(id=ident), 'metadata'),
            'image': send_request(ident, idx, image_uri.format(id=ident[4:]), 'image'),
            'alto': send_request(ident, idx, alto_uri.format(id=ident[4:]), 'alto'),
            'ocr': send_request(ident, idx, ocr_uri.format(id=ident[4:]), 'ocr'),
        }
        print(f"Finished fetching the data for identifier {ident} ({idx+1}/{len(sample_ids)})")
        fetched_data[ident] = fetched_for_id

    return fetched_data

# %%
for idx, ident in enumerate(sample_ids):
    print(f"Fetching the data for identifier {ident} ({idx+1}/{len(sample_ids)})")
    # for images, ocr, and alto, the firs "anp:" should be removed
    fetched_for_id = {
        'metadata': send_request(ident, idx, metadata_uri.format(id=ident), 'metadata'),
        'image': send_request(ident, idx, image_uri.format(id=ident[4:]), 'image'),
        'alto': send_request(ident, idx, alto_uri.format(id=ident[4:]), 'alto'),
        'ocr': send_request(ident, idx, ocr_uri.format(id=ident[4:]), 'ocr'),
    }
    print(f"Finished fetching the data for identifier {ident} ({idx+1}/{len(sample_ids)})")
    fetched_data[ident] = fetched_for_id
# Out:
# Fetching the data for identifier anp:anp:1937:03:01:5:mpeg21 (1/5)
# anp:anp:1937:03:01:5:mpeg21 (1) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:01:5:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:01:5:mpeg21 (1) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:image
# anp:anp:1937:03:01:5:mpeg21 (1) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:alto
# anp:anp:1937:03:01:5:mpeg21 (1) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:01:5:mpeg21 (1/5)
# Fetching the data for identifier anp:anp:1937:03:25:4:mpeg21 (2/5)
# anp:anp:1937:03:25:4:mpeg21 (2) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:25:4:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:25:4:mpeg21 (2) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:25:4:mpeg21:image
# anp:anp:1937:03:25:4:mpeg21 (2) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:25:4:mpeg21:alto
# anp:anp:1937:03:25:4:mpeg21 (2) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:25:4:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:25:4:mpeg21 (2/5)
# Fetching the data for identifier anp:anp:1937:03:02:3:mpeg21 (3/5)
# anp:anp:1937:03:02:3:mpeg21 (3) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:02:3:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:02:3:mpeg21 (3) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:02:3:mpeg21:image
# anp:anp:1937:03:02:3:mpeg21 (3) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:02:3:mpeg21:alto
# anp:anp:1937:03:02:3:mpeg21 (3) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:02:3:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:02:3:mpeg21 (3/5)
# Fetching the data for identifier anp:anp:1937:12:31:5:mpeg21 (4/5)
# anp:anp:1937:12:31:5:mpeg21 (4) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:12:31:5:mpeg21&metadataPrefix=didl
# anp:anp:1937:12:31:5:mpeg21 (4) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:12:31:5:mpeg21:image
# anp:anp:1937:12:31:5:mpeg21 (4) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:12:31:5:mpeg21:alto
# anp:anp:1937:12:31:5:mpeg21 (4) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:12:31:5:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:12:31:5:mpeg21 (4/5)
# Fetching the data for identifier anp:anp:1937:11:28:1:mpeg21 (5/5)
# anp:anp:1937:11:28:1:mpeg21 (5) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:11:28:1:mpeg21&metadataPrefix=didl
# anp:anp:1937:11:28:1:mpeg21 (5) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:11:28:1:mpeg21:image
# anp:anp:1937:11:28:1:mpeg21 (5) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:11:28:1:mpeg21:alto
# anp:anp:1937:11:28:1:mpeg21 (5) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:11:28:1:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:11:28:1:mpeg21 (5/5)

# %%
fetched_data['anp:anp:1937:03:01:5:mpeg21']['alto']
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <alto xmlns:xlink="http://www.w3.org/TR/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="http://schema.ccs-gmbh.com/metae/alto-1-2.xsd">
# <Description><MeasurementUnit>pixel</MeasurementUnit></Description>
# <Layout>
# <Page HEIGHT="1958" ID="Page1" PHYSICAL_IMG_NR="1" WIDTH="1240">
# <PrintSpace HEIGHT="1958" HPOS="0" VPOS="0" WIDTH="1240">
# <TextBlock HEIGHT="38" HPOS="156" ID="TextBlock1" VPOS="61" WIDTH="960">
# <TextLine HEIGHT="31" HPOS="165" ID="TextLine1" VPOS="66" WIDTH="943">
# <String CONTENT="RADICBFIICHTGEVING" HEIGHT="20" HPOS="165" ID="String1" VPOS="73" WIDTH="269"/>
# <SP HPOS="434" ID="SP1" VPOS="92" WIDTH="20"/>
# <String CONTENT="lUITTh" HEIGHT="18" HPOS="454" ID="String2" VPOS="72" WIDTH="94"/>
# <String CONTENT="'" HEIGHT="2" HPOS="547" ID="String3" VPOS="72" WIDTH="2"/>
# <SP HPOS="548" ID="SP2" VPOS="90" WIDTH="8"/>
# <String CONTENT="AND" HEIGHT="19" HPOS="555" ID="String4" VPOS="71" WIDTH="45"/>
# <SP HPOS="600" ID="SP3" VPOS="89" WIDTH="15"/>
# <String CONTENT="van" HEIGHT="13" HPOS="614" ID="String5" VPOS="73" WIDTH="46"/>
# <SP HPOS="660" ID="SP4" VPOS="86" WIDTH="17"/>
# <String CONTENT="1" HEIGHT="18" HPOS="676" ID="String6" VPOS="68" WIDTH="12"/>
# <SP HPOS="688" ID="SP5" VPOS="85" WIDTH="18"/>
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <text>
# <p>RADICBFIICHTGEVING lUITTh' AND van 1 yaart $7. tweede uitzending </p>
# <p>In de Giornale ditalia komt Virginio Gayda terug op eer artikel, dat hy onlangs over de kwestie van de restauratie dec Habsburgers in OoStenryk hepft geschreven. Hy bevestigt nadrukkelyk, dal genoemd artikel-  de houding weergeeft, welke Italie tegenover de binnenlandsche politiek van Oostenryk zal aannemen en die berust op het principe van de politieke onafhamkelykheid en onschendbaarheid van O-stenryk mer erkenning van het onvervreemdbaar karakter van Duitsche-gatie, z^. als in de Buitsch-Jostenryksche overeenkomst v -' 1 Juli is vastgesteld. Wy bevestigen, aldus Gayda, dat de restauratie, onafhan- kelyk van de gezichtspunten xx ten aanzien van hi dynastie der Hahsburgers, niet actueel en dus gevasrlyk is. Hii.' a r_ oegt de schryver toe, dat niets in de politieke daden, noch selhs in de journalistieke-  litteratuur XKXRRxiE de meening zou kunne a wettigen, dat Italie tegenover een herstel der Habsburgers gunstig zou staan. In dit verband wordt heriiacrd aan een artikel in de popoio d Italia, dat naar mei meent te weten door den Duce zelf zou zyr geschreven, en waarin een uiterst ?elüen toon tegen den kroonpreterdent otto weerklonk. Dit Italiaansch verzet togen een eventueelen tera^kcr van&lt; utto van' absburg op den troon zyner vaderen wordt in het Duitsche blad 'Angriff' geestdriftig toegejuicht. Deze Duitsche krant, die een feilen aanval op de dynastie er habsburgers doet, constateert zelfs, dat de zaak xaxcjaexdyoHCXA der Habsburgers geliquideerd fs. Volgens de Angriff zou in een groot deel van Europa de openbare reening een herstel van d&amp; RXËExtEXËykXBRKHxRKXER de Habsbur^Trs or den troon vyandig gezind zyn. Volgens een bericht uit home heeft geRexcRc eereraad, die beàast was met de regeling vai het geschil tusschen maarschalk de Bono enden minister van koloniën Lessona in een communique verklaard, dat xy ^r geen factoren zyn, welke een ontmoeting op de wapenen Xxx tusschen deze beide ho&lt; r; e functionarissen zouden kunnen rechtvaardigen. In de Italiaansche hoofdstad gar t opnieuw het geracht, dat mogelyk binnenkort wyziringen in de regeering worden gebracht. In dit verband-  wordt o. m. gesproken ov^r een vervanging vai den minister van lolonien, et een balangryke missie naar Oost-Afrikr zou worden belast. -^Fet groote belangstelling word^^ p besluitcr, v. *nl4M&lt;. ^o -( /^ 9«tHBavoRd byeengekomen^arocte fascistische raad z^èMrr^n, afgewacht, Aan het ^adrileensche front is het vandaag tamelyk rustig geweest. Slechts op den weg naar La Coruna is het tot een kort eoch hevig xxfB treffen tusschen de beide partyen gekomen. tillerie van de regeringstroepen, die een lEXKHXg levendig sp a onderhield, ^?°§S er belangryk toe by, dat de aanvallende troeoen ven Franco ten- siotTe tot den aftocht ar; den gedwongen. </p>
# </text>

# %%
fetched_data['anp:anp:1937:03:01:5:mpeg21']['metadata']
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/          http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">
# <responseDate>2025-01-17T15:17:50.079Z</responseDate>
# <request metadataPrefix="didl" verb="GetRecord">http://services.kb.nl/mdo/oai	</request>
# <GetRecord>
# <record>
# <header>
# <identifier>anp:anp:1937:03:01:5:mpeg21</identifier>
# <datestamp>2008-09-24T09:09:18.300Z</datestamp>
# <setSpec>anp</setSpec>
# </header>
# <metadata>
# <didl:DIDL xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcmitype="http://purl.org/dc/dcmitype/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:dcx="http://krait.kb.nl/coop/tel/handbook/telterms.html" xmlns:didl="urn:mpeg:mpeg21:2002:02-DIDL-NS" xmlns:srw_dc="info:srw/schema/1/dc-v1.1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><didl:Item dc:identifier="anp:1937:03:01:5:mpeg21"><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:metadata"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">metadata</didl:Statement></didl:Descriptor><didl:Resource mimeType="text/xml"><srw_dc:dcx xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
# <dc:identifier>http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21</dc:identifier>
# <dcx:recordIdentifier>anp:1937:03:01:5</dcx:recordIdentifier>
# <dcterms:isPartOf>ANP</dcterms:isPartOf>
# <dcterms:isPartOf>ANP Nieuwsberichten 1937-1989</dcterms:isPartOf>
# <dc:type xsi:type="dcterms:DCMIType">Text</dc:type>
# <dcterms:medium xsi:type="dcterms:IMT">image/jpg</dcterms:medium>
# <dc:language xsi:type="ISO-639-2">dut</dc:language>
# <dc:rights>ANP</dc:rights>
# <dcx:recordRights>Koninklijke Bibliotheek, Den Haag</dcx:recordRights>
# <dc:title>ANP Nieuwsbericht - 01-03-1937 - 5</dc:title>
# <dc:date>1937-03-01</dc:date>
# <dcx:volgnummer>5</dcx:volgnummer>
# </srw_dc:dcx>
# </didl:Resource></didl:Component><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:image"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">image</didl:Statement></didl:Descriptor><didl:Resource mimeType="image/jpeg" ref="anp_1937-03-01_5_access.jpg"/><didl:Resource mimeType="image/jpeg" ref="http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:image"/></didl:Component><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:alto"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">alto</didl:Statement></didl:Descriptor><didl:Resource mimeType="text/xml" ref="anp_1937-03-01_5_alto.xml"/><didl:Resource mimeType="text/xml" ref="http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:alto"/></didl:Component><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:ocr"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">ocr</didl:Statement></didl:Descriptor><didl:Resource mimeType="text/xml" ref="anp_1937-03-01_5_text.xml"/><didl:Resource mimeType="text/xml" ref="http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:ocr"/></didl:Component></didl:Item></didl:DIDL>
# </metadata>
# </record>
# </GetRecord>
# </OAI-PMH>

# %%
fetched_data
# Out:
# {'anp:anp:1937:03:01:5:mpeg21': {'metadata': <?xml version="1.0" encoding="utf-8"?>
#   <OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/          http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">
#   <responseDate>2025-01-17T15:17:50.079Z</responseDate>
#   <request metadataPrefix="didl" verb="GetRecord">http://services.kb.nl/mdo/oai	</request>
#   <GetRecord>
#   <record>
#   <header>
#   <identifier>anp:anp:1937:03:01:5:mpeg21</identifier>
#   <datestamp>2008-09-24T09:09:18.300Z</datestamp>
#   <setSpec>anp</setSpec>
#   </header>
#   <metadata>
#   <didl:DIDL xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:dcmitype="http://purl.org/dc/dcmitype/" xmlns:dcterms="http://purl.org/dc/terms/" xmlns:dcx="http://krait.kb.nl/coop/tel/handbook/telterms.html" xmlns:didl="urn:mpeg:mpeg21:2002:02-DIDL-NS" xmlns:srw_dc="info:srw/schema/1/dc-v1.1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><didl:Item dc:identifier="anp:1937:03:01:5:mpeg21"><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:metadata"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">metadata</didl:Statement></didl:Descriptor><didl:Resource mimeType="text/xml"><srw_dc:dcx xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
#   <dc:identifier>http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21</dc:identifier>
#   <dcx:recordIdentifier>anp:1937:03:01:5</dcx:recordIdentifier>
#   <dcterms:isPartOf>ANP</dcterms:isPartOf>
#   <dcterms:isPartOf>ANP Nieuwsberichten 1937-1989</dcterms:isPartOf>
#   <dc:type xsi:type="dcterms:DCMIType">Text</dc:type>
#   <dcterms:medium xsi:type="dcterms:IMT">image/jpg</dcterms:medium>
#   <dc:language xsi:type="ISO-639-2">dut</dc:language>
#   <dc:rights>ANP</dc:rights>
#   <dcx:recordRights>Koninklijke Bibliotheek, Den Haag</dcx:recordRights>
#   <dc:title>ANP Nieuwsbericht - 01-03-1937 - 5</dc:title>
#   <dc:date>1937-03-01</dc:date>
#   <dcx:volgnummer>5</dcx:volgnummer>
#   </srw_dc:dcx>
#   </didl:Resource></didl:Component><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:image"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">image</didl:Statement></didl:Descriptor><didl:Resource mimeType="image/jpeg" ref="anp_1937-03-01_5_access.jpg"/><didl:Resource mimeType="image/jpeg" ref="http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:image"/></didl:Component><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:alto"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">alto</didl:Statement></didl:Descriptor><didl:Resource mimeType="text/xml" ref="anp_1937-03-01_5_alto.xml"/><didl:Resource mimeType="text/xml" ref="http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:alto"/></didl:Component><didl:Component dc:identifier="anp:1937:03:01:5:mpeg21:ocr"><didl:Descriptor><didl:Statement dc:type="role" mimeType="text/plain">ocr</didl:Statement></didl:Descriptor><didl:Resource mimeType="text/xml" ref="anp_1937-03-01_5_text.xml"/><didl:Resource mimeType="text/xml" ref="http://resolver.kb.nl/resolve?urn=anp:1937:03:01:5:mpeg21:ocr"/></didl:Component></didl:Item></didl:DIDL>
#   </metadata>
#   </record>
#   </GetRecord>
#   </OAI-PMH>,
#   'image': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x01\x01,\x01,\x00\x00\xff\xdb\x00C\x00\x0c\r\r\x0e\x0e\x0e\x12\x12\x12\x12\x18\x15\x16\x15\x18\x1e\x19\x1a\x1a\x19\x1e& \x1f!\x1f &1(&((&(13/030/3::>>::FJMJFY^^Yrvr\x92\x92\xb9\xff\xdb\x00C\x01\x0c\x12\x12\x12\x12\x12\x12\x14\x16\x1e+\x1f\x1a\x17\x15\x18\x1a #->Z@1*\'\x1e\x1e$#-49E[\x82\x84aND?4*<KS[l\x8c\x99|meXz\x85\x92\xad\xca\xb2\xa4\xdb\xf3\xff\xff\xc0\x00\x0b\x08\x0fB\t\xa0\x01\x01\x11\x00\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz!Scanned by Kodak i600          \xff\xda\x00\x08\x01\x01\x00\x00?\x00\xe9\x88\xe2\x90\x9c\np\xe9K\xc5-\'J_\xc6\x90\xd3\x08\xcd4\xa9\xf5\xa4\xe0Rpi3\xf9R\xf4\xa0\xf3\xedI\xf8\xd0=)F\x06i\x8cs\x9cR\x83\x81\xd74pzqK\x9aw\x14\x999\xc55G4\xea0)\xb9\xedO\xfci\x0e\r;\x8a84*\xe2\x94\xe0\x8a;R\x0eGZQ\xc5.}\xa91K\x8c\xd2\x9c\xf6\xa0\xd3ON\xb4\xean\x14R\xfdi\x00\x02\x9d\x9c\x8eM \x19\xe2\x9c\x17\x1cR\x90)\xb8\xa4\xe0\x1eih\xc0\xc53h\xc5.\x00\xa7qH\xc6\x93\x83\xd6\x9az\
#   <p>SPORT. Turnen. De eindstrijden van de Nederlandsche tumkamploenschappen voor dames en heeren, en voor do samenstelling van de keurkorps/en voor 1938 zijn vandaag te DORDRECHT ^e%±R3*g#. Van de heeren werd do hoor H. KOK van SPARTA uit KRIMPEN aan de LEK kampioen mot 95 3/^ punt, en van de dames mej. T. PAEZENS van D. O. S. uit AMSTERDAM met I07 punten. Zwammen. Bij de Internationale zwemwedstrijden te ANTWERPEN, waamede het Koningin Astrid-bad, werd geopend/, hebbon vandaag ohk de Nederlandsche deelnemers-  succes gehad. Bij de 200 motor schoolslag dames werd JOPIE STR00M- ^ BERG eerste in 3 min. 10, 1 sec. voor; aej. KLEINOOT. De 200 meter rugslag dames bracht een overwinning voor IET VAN FEGGELEN in 2 min. ^8, 1 sas.; tweede-  werd COR KINT on derde DINI KERKMEESTER. Bij het schoonspringen werd onze langgenoot SCHATENS eerste met 137, 6 pant^, en bij do 200 meter rug- slgg^heoren bezette METMAN Be twoede plaats, achter den Hongaar LENGYEL. de 200 M. schoolslag hoeren werd gewonnen door SMITSHUIZEN met 2 min. 50sec. De. waterplowodstrijd tusschen HET Y en K. A. Z. T. bracht een 8-2 overwinning voor de Amsterdammers. C. N. B, won van BOEDAPEST mot i+-3. </p>
#   </text>}}

# %%
kb_radio_test_img_file_2 = os.path.join(kb_radio_sample_path, "test_img_2.jpg")

with open(kb_radio_test_img_file_2, 'wb') as handler:
    handler.write(fetched_data['anp:anp:1937:12:10:1:mpeg21']['image'])

# %% [markdown]
# #### Saving all queried data to disk in the file-structure that we expect

# %%
fetched_data['anp:anp:1937:03:01:5:mpeg21']['metadata'].find_all('isPartOf')[-1].get_text()
# Out:
# 'ANP Nieuwsberichten 1937-1989'

# %%
def extract_path(record_metadata, base_path = kb_radio_sample_path):

    collection = record_metadata.find_all('isPartOf')[-1].get_text()
    date_str = record_metadata.date.get_text()
    date_as_path = date_str.replace('-', '/')

    title = record_metadata.title.get_text()
    vol_number = record_metadata.volgnummer.get_text()

    record_id = record_metadata.recordIdentifier.get_text().replace(":", "_")

    return record_id, os.path.join(base_path, collection.replace(' ', '_'), date_as_path, vol_number, record_id)

# %%
def write_fetched_Data_to_disk(fetched):
    for ident, radio_data in fetched.items():
    
        print(f"Writing all the data for {ident} to disk.")
        # create a path for the sample from the metadata
        record_id, full_sample_path = extract_path(radio_data['metadata'])
        print(f" {ident} - sample path = {full_sample_path}")

        os.makedirs(full_sample_path, exist_ok=True)
        # define each path from it
        full_metadata_path = os.path.join(full_sample_path, f"{record_id}_metadata.xml")
        full_img_path = os.path.join(full_sample_path, f"{record_id}.jpg")
        full_alto_path = os.path.join(full_sample_path, f"{record_id}_alto.xml")
        full_ocr_path = os.path.join(full_sample_path, f"{record_id}_ocr_text.xml")

        # write all extracted data to file
        with open(full_metadata_path, 'w', encoding='utf-8') as handler:
            handler.write(str(radio_data['metadata']))
        with open(full_img_path, 'wb') as handler:
            handler.write(radio_data['image'])
        with open(full_alto_path, 'w', encoding='utf-8') as handler:
            handler.write(str(radio_data['alto']))
        with open(full_ocr_path, 'w', encoding='utf-8') as handler:
            handler.write(str(radio_data['ocr']))

# %%
for ident, radio_data in fetched_data.items():
    
    print(f"Writing all the data for {ident} to disk.")
    # create a path for the sample from the metadata
    record_id, full_sample_path = extract_path(radio_data['metadata'])
    print(f" {ident} - sample path = {full_sample_path}")

    os.makedirs(full_sample_path, exist_ok=True)
    # define each path from it
    full_metadata_path = os.path.join(full_sample_path, f"{record_id}_metadata.xml")
    full_img_path = os.path.join(full_sample_path, f"{record_id}.jpg")
    full_alto_path = os.path.join(full_sample_path, f"{record_id}_alto.xml")
    full_ocr_path = os.path.join(full_sample_path, f"{record_id}_ocr_text.xml")

    # write all extracted data to file
    with open(full_metadata_path, 'w', encoding='utf-8') as handler:
        handler.write(str(radio_data['metadata']))
    with open(full_img_path, 'wb') as handler:
        handler.write(radio_data['image'])
    with open(full_alto_path, 'w', encoding='utf-8') as handler:
        handler.write(str(radio_data['alto']))
    with open(full_ocr_path, 'w', encoding='utf-8') as handler:
        handler.write(str(radio_data['ocr']))
# Out:
# Writing all the data for anp:anp:1937:03:01:5:mpeg21 to disk.
#  anp:anp:1937:03:01:5:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/01/5/anp_1937_03_01_5
# Writing all the data for anp:anp:1937:03:25:4:mpeg21 to disk.
#  anp:anp:1937:03:25:4:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/25/4/anp_1937_03_25_4
# Writing all the data for anp:anp:1937:03:02:3:mpeg21 to disk.
#  anp:anp:1937:03:02:3:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/02/3/anp_1937_03_02_3
# Writing all the data for anp:anp:1937:12:31:5:mpeg21 to disk.
#  anp:anp:1937:12:31:5:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/12/31/5/anp_1937_12_31_5
# Writing all the data for anp:anp:1937:11:28:1:mpeg21 to disk.
#  anp:anp:1937:11:28:1:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/11/28/1/anp_1937_11_28_1

# %% [markdown]
# #### Repeat approach for all the samples of some days
#
# In order to know if all the elements of a given day are actually from the same bulletin or not, we need to download all the samples of a given day.

# %%
day_of_interest = ':'.join(sample_ids[0].split(':')[2:5])
sample_ids[0], day_of_interest
# Out:
# ('anp:anp:1937:03:01:5:mpeg21', '1937:03:01')

# %%
same_day_ids = [i for i in identifiers_data if day_of_interest in i and i!= sample_ids[0]]
len(same_day_ids), same_day_ids
# Out:
# (6,
#  ['anp:anp:1937:03:01:1:mpeg21',
#   'anp:anp:1937:03:01:4:mpeg21',
#   'anp:anp:1937:03:01:3:mpeg21',
#   'anp:anp:1937:03:01:2:mpeg21',
#   'anp:anp:1937:03:01:6:mpeg21',
#   'anp:anp:1937:03:01:7:mpeg21'])

# %%
same_day_fetched = fetch_data_for_identifiers(same_day_ids)
# Out:
# Fetching the data for identifier anp:anp:1937:03:01:1:mpeg21 (1/5)
# anp:anp:1937:03:01:1:mpeg21 (1) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:01:1:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:01:1:mpeg21 (1) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:1:mpeg21:image
# anp:anp:1937:03:01:1:mpeg21 (1) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:1:mpeg21:alto
# anp:anp:1937:03:01:1:mpeg21 (1) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:1:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:01:1:mpeg21 (1/5)
# Fetching the data for identifier anp:anp:1937:03:01:4:mpeg21 (2/5)
# anp:anp:1937:03:01:4:mpeg21 (2) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:01:4:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:01:4:mpeg21 (2) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:4:mpeg21:image
# anp:anp:1937:03:01:4:mpeg21 (2) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:4:mpeg21:alto
# anp:anp:1937:03:01:4:mpeg21 (2) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:4:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:01:4:mpeg21 (2/5)
# Fetching the data for identifier anp:anp:1937:03:01:3:mpeg21 (3/5)
# anp:anp:1937:03:01:3:mpeg21 (3) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:01:3:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:01:3:mpeg21 (3) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:3:mpeg21:image
# anp:anp:1937:03:01:3:mpeg21 (3) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:3:mpeg21:alto
# anp:anp:1937:03:01:3:mpeg21 (3) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:3:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:01:3:mpeg21 (3/5)
# Fetching the data for identifier anp:anp:1937:03:01:2:mpeg21 (4/5)
# anp:anp:1937:03:01:2:mpeg21 (4) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:01:2:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:01:2:mpeg21 (4) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:2:mpeg21:image
# anp:anp:1937:03:01:2:mpeg21 (4) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:2:mpeg21:alto
# anp:anp:1937:03:01:2:mpeg21 (4) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:2:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:01:2:mpeg21 (4/5)
# Fetching the data for identifier anp:anp:1937:03:01:6:mpeg21 (5/5)
# anp:anp:1937:03:01:6:mpeg21 (5) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:01:6:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:01:6:mpeg21 (5) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:6:mpeg21:image
# anp:anp:1937:03:01:6:mpeg21 (5) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:6:mpeg21:alto
# anp:anp:1937:03:01:6:mpeg21 (5) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:6:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:01:6:mpeg21 (5/5)
# Fetching the data for identifier anp:anp:1937:03:01:7:mpeg21 (6/5)
# anp:anp:1937:03:01:7:mpeg21 (6) - sending the resquest for metadata, uri=http://services.kb.nl/mdo/oai?verb=GetRecord&identifier=anp:anp:1937:03:01:7:mpeg21&metadataPrefix=didl
# anp:anp:1937:03:01:7:mpeg21 (6) - sending the resquest for image, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:7:mpeg21:image
# anp:anp:1937:03:01:7:mpeg21 (6) - sending the resquest for alto, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:7:mpeg21:alto
# anp:anp:1937:03:01:7:mpeg21 (6) - sending the resquest for ocr, uri=http://resolver.kb.nl/resolve?urn=anp:1937:03:01:7:mpeg21:ocr
# Finished fetching the data for identifier anp:anp:1937:03:01:7:mpeg21 (6/5)

# %%
write_fetched_Data_to_disk(same_day_fetched)
# Out:
# Writing all the data for anp:anp:1937:03:01:1:mpeg21 to disk.
#  anp:anp:1937:03:01:1:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/01/1/anp_1937_03_01_1
# Writing all the data for anp:anp:1937:03:01:4:mpeg21 to disk.
#  anp:anp:1937:03:01:4:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/01/4/anp_1937_03_01_4
# Writing all the data for anp:anp:1937:03:01:3:mpeg21 to disk.
#  anp:anp:1937:03:01:3:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/01/3/anp_1937_03_01_3
# Writing all the data for anp:anp:1937:03:01:2:mpeg21 to disk.
#  anp:anp:1937:03:01:2:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/01/2/anp_1937_03_01_2
# Writing all the data for anp:anp:1937:03:01:6:mpeg21 to disk.
#  anp:anp:1937:03:01:6:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/01/6/anp_1937_03_01_6
# Writing all the data for anp:anp:1937:03:01:7:mpeg21 to disk.
#  anp:anp:1937:03:01:7:mpeg21 - sample path = /home/piconti/impresso-text-acquisition/text_preparation/data/sample_data/KB/radio/ANP_Nieuwsberichten_1937-1989/1937/03/01/7/anp_1937_03_01_7
